# %% [markdown]
# # Introduction

# %% [markdown]
# <center><img src="https://i.imgur.com/9hLRsjZ.jpg" height=400></center>
#
# This dataset was scraped from [nextspaceflight.com](https://nextspaceflight.com/launches/past/?page=1) and includes all the space missions since the beginning of Space Race between the USA and the Soviet Union in 1957!

# %% [markdown]
# ### Install Package with Country Codes

# %%
# %pip install iso3166

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab.

# %%
# %pip install --upgrade plotly

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# These might be helpful:
from iso3166 import countries
from datetime import datetime, timedelta

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load the Data

# %%
df_data = pd.read_csv('mission_launches.csv')

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                          Date                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Rocket_Status  Price Mission_Status
# 0  StatusActive   50.0        Success
# 1  StatusActive  29.75        Success
# 2  StatusActive    NaN        Success
# 3  StatusActive   65.0        Success
# 4  StatusActive  145.0        Success

# %%
print(f"NaN values: {df_data.isnull().values.any()}")
print(f"Duplicate rows: {df_data.duplicated().any()}")
# Out:
# NaN values: True
# Duplicate rows: False

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider removing columns containing junk data.

# %%
df_data.dropna(inplace=True)

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0
# count        964.00      964.00
# mean         858.49      858.49
# std          784.21      784.21
# min            0.00        0.00
# 25%          324.75      324.75
# 50%          660.50      660.50
# 75%        1,112.00    1,112.00
# max        4,020.00    4,020.00

# %% [markdown]
# # Number of Launches per Company
#
# Create a chart that shows the number of space mission launches by organisation.

# %%
launches_by_company = df_data.groupby('Organisation')['Organisation'].count()
launches_by_company.sort_values(ascending=False, inplace=True)
launches_by_company

# %%
fig = px.bar(x=launches_by_company.index,
             y=launches_by_company.values,
             title="Launches Per Company",
             color=launches_by_company.index )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4c0ec4a6-b2d2-4c81-b76a-c24d341b0b75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4c0ec4a6-b2d2-4c81-b76a-c24d341b0b75")) {                    Plotly.newPlot(                        "4c0ec4a6-b2d2-4c81-b76a-c24d341b0b75",                        [{"hovertemplate":"color=CASC\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CASC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CASC","orientation":"v","showlegend":true,"textposition":"auto","x":["CASC"],"xaxis":"x","y":{"dtype":"i2","bdata":"ngA="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=NASA\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"NASA","orientation":"v","showlegend":true,"textposition":"auto","x":["NASA"],"xaxis":"x","y":{"dtype":"i2","bdata":"lQA="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=SpaceX\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SpaceX","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"SpaceX","orientation":"v","showlegend":true,"textposition":"auto","x":["SpaceX"],"xaxis":"x","y":{"dtype":"i1","bdata":"Yw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=ULA\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ULA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ULA","orientation":"v","showlegend":true,"textposition":"auto","x":["ULA"],"xaxis":"x","y":{"dtype":"i1","bdata":"Yg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=Arianespace\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arianespace","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Arianespace","orientation":"v","showlegend":true,"textposition":"auto","x":["Arianespace"],"xaxis":"x","y":{"dtype":"i1","bdata":"YA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=Northrop\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northrop","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Northrop","orientation":"v","showlegend":true,"textposition":"auto","x":["Northrop"],"xaxis":"x","y":{"dtype":"i1","bdata":"Uw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=ISRO\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISRO","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ISRO","orientation":"v","showlegend":true,"textposition":"auto","x":["ISRO"],"xaxis":"x","y":{"dtype":"i1","bdata":"Qw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=MHI\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MHI","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"MHI","orientation":"v","showlegend":true,"textposition":"auto","x":["MHI"],"xaxis":"x","y":{"dtype":"i1","bdata":"JQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=VKS RF\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"VKS RF","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"VKS RF","orientation":"v","showlegend":true,"textposition":"auto","x":["VKS RF"],"xaxis":"x","y":{"dtype":"i1","bdata":"IQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"color=US Air Force\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"US Air Force","orientation":"v","showlegend":true,"textposition":"auto","x":["US Air Force"],"xaxis":"x","y":{"dtype":"i1","bdata":"Gg=="},"ya ...

# %% [markdown]
# # Number of Active versus Retired Rockets
#
# How many rockets are active compared to those that are decomissioned?

# %%
active_vs_retired_rockets = df_data.groupby('Rocket_Status').agg({'Rocket_Status': 'count'})
active_vs_retired_rockets
# Out:
#                Rocket_Status
# Rocket_Status
# StatusActive             586
# StatusRetired            378

# %% [markdown]
# # Distribution of Mission Status
#
# How many missions were successful?
# How many missions failed?

# %%
successful_vs_failed_missions = df_data.groupby('Mission_Status').agg({'Mission_Status': 'count'})
successful_vs_failed_missions
# Out:
#                    Mission_Status
# Mission_Status
# Failure                        36
# Partial Failure                17
# Prelaunch Failure               1
# Success                       910

# %% [markdown]
# # How Expensive are the Launches?
#
# Create a histogram and visualise the distribution. The price column is given in USD millions (careful of missing values).

# %%
df_price = df_data.dropna(subset=['Price'])
price_graph = px.histogram(df_price,
                           x='Price',
                           nbins=20,
                           title='Distribution of Launch Prices (USD Millions)',
                           labels={'Price': 'Launch Price (USD Millions)'}
                          )
price_graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="585ecffe-7637-40af-9473-2e995d1b5949" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("585ecffe-7637-40af-9473-2e995d1b5949")) {                    Plotly.newPlot(                        "585ecffe-7637-40af-9473-2e995d1b5949",                        [{"bingroup":"x","hovertemplate":"Launch Price (USD Millions)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"orientation":"v","showlegend":false,"x":["50.0","29.75","65.0","145.0","64.68","48.5","50.0","90.0","46.0","28.3","29.15","29.75","7.5","64.68","50.0","29.15","29.75","50.0","7.5","30.8","50.0","29.75","50.0","5.3","12.0","112.5","120.0","48.5","50.0","29.15","48.5","153.0","30.8","48.5","50.0","29.15","50.0","48.5","29.75","200.0","50.0","85.0","115.0","90.0","48.5","7.5","50.0","50.0","200.0","29.75","29.15","50.0","41.8","65.0","64.68","50.0","21.0","48.5","48.5","7.5","50.0","64.68","31.0","200.0","50.0","29.15","64.68","85.0","29.15","7.5","40.0","65.0","64.68","48.5","29.75","112.5","5.3","64.68","41.8","164.0","48.5","7.5","29.15","7.5","153.0","50.0","200.0","65.0","48.5","48.5","30.8","50.0","62.0","65.0","37.0","7.5","90.0","29.15","200.0","50.0","5.3","65.0","50.0","64.68","21.0","7.5","50.0","64.68","29.15","85.0","90.0","48.5","21.0","29.15","7.5","37.0","29.15","50.0","50.0","200.0","5.3","350.0","39.0","50.0","29.15","48.5","50.0","5.3","65.0","47.0","7.5","29.15","29.75","50.0","200.0","50.0","41.8","21.0","37.0","29.75","85.0","50.0","62.0","7.5","48.5","29.15","90.0","30.8","35.0","64.68","200.0","153.0","30.8","50.0","200.0","112.5","21.0","50.0","30.8","37.0","350.0","50.0","64.68","50.0","50.0","48.5","69.7","30.8","62.0","30.8","90.0","69.7","62.0","29.75","62.0","85.0","64.68","50.0","64.68","109.0","29.15","5.3","41.8","62.0","65.0","153.0","31.0","64.68","200.0","62.0","64.68","62.0","47.0","29.75","62.0","145.0","90.0","62.0","48.5","90.0","29.75","48.5","62.0","200.0","30.8","7.5","115.0","5.3","39.0","29.75","31.0","29.75","62.0","30.8","29.75","62.0","90.0","62.0","29.15","29.75","35.0","30.8","64.68","85.0","37.0","45.0","62.0","123.0","48.5","41.8","62.0","90.0","62.0","29.75","200.0","30.8","65.0","145.0","65.0","62.0","31.0","46.0","62.0","109.0","65.0","62.0","37.0","48.5","62.0","200.0","62.0","62.0","31.0","29.15","64.68","48.5","65.0","62.0","62.0","200.0","90.0","7.5","62.0","47.0","200.0","62.0","109.0","29.15","62.0","90.0","62.0","37.0","109.0","62.0","31.0","200.0","109.0","62.0","29.15","29.75","200.0","29.75","130.0","40.0","29.15","112.5","31.0","37.0","145.0","29.75","109.0","5.3","90.0","85.0","200.0","25.0","37.0","115.0","47.0","62.0","64.68","200.0","164.0","29.75","62.0","64.68","29.15","123.0","62.0","64.68","153.0","31.0","200.0","62.0","350.0","65.0","41.8","64.68","48.5","62.0","29.75","62.0","31.0","62.0","29.75","48.5","69.7","48.5","109.0","65.0","35.0","31.0","200.0","62.0","90.0","41.8","48.5","109.0","65.0","200.0","31.0","56.5","29.15","62.0","21.0","109.0","37.0","200.0","15.0","109.0","109.0","123.0","200.0","31.0","5.3","41.8","153.0","47.0","200.0","112.5","200.0","109.0","31.0","56.5","37.0","200.0","120.0","56.5","200.0","56.5","41.8","31.0","90.0","29.0","164.0","123.0","56.5","56.5","37.0","90.0","153.0","56.5","62.0","145.0","200.0","350.0","90.0","29.0","109.0","80.0","200.0","31.0","90.0","56.5","109.0","200.0","56.5","109.0","56.5","109.0","164.0","56.5","80.0","41.8","21.0","29.0","90.0","41.8","109.0","164.0","37.0","56.5","145.0","31.0","109.0","200.0","90.0","164.0","200.0","109.0","80.0","56.5","47.0","41.8","120.0","56.5","41.8","29.0","40.0","109.0","31.0","56.5","140.0","80.0","41.8","55.0","200.0", ...

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Launches by Country
#
# * Create a choropleth map using [the plotly documentation](https://plotly.com/python/choropleth-maps/)
# * Experiment with [plotly's available colours](https://plotly.com/python/builtin-colorscales/). I quite like the sequential colour `matter` on this map.
# * You'll need to extract a `country` feature as well as change the country names that no longer exist.
#
# Wrangle the Country Names
#
# You'll need to use a 3 letter country code for each country. You might have to change some country names.
#
# * Russia is the Russian Federation
# * New Mexico should be USA
# * Yellow Sea refers to China
# * Shahrud Missile Test Site should be Iran
# * Pacific Missile Range Facility should be USA
# * Barents Sea should be Russian Federation
# * Gran Canaria should be USA
#
#
# You can use the iso3166 package to convert the country names to Alpha3 format.

# %%
df_data['Country'] = df_data['Location'].str.split(',').str[-1].str.strip()
df_data['Country'].unique()
df_data['Country']

replaced_countries = {
    'Russia': 'Russian Federation',
    'New Mexico': 'USA',
    'Yellow Sea': 'China',
    'Shahrud Missile Test Site': 'Iran',
    'Pacific Missile Range Facility': 'USA',
    'Barents Sea': 'Russian Federation',
    'Gran Canaria': 'USA'
}

df_data['Country'].replace(replaced_countries)
# Out:
# 0              USA
# 1            China
# 3       Kazakhstan
# 4              USA
# 5            China
#            ...
# 3855           USA
# 3971           USA
# 3993           USA
# 4000           USA
# 4020           USA
# Name: Country, Length: 964, dtype: object

# %%
def get_country_code(country):
    try:
        return countries.get(country).alpha3
    except:
        return np.nan

df_data['Country_Code'] = df_data['Country'].apply(get_country_code)

launches_by_country = df_data.groupby('Country_Code')['Country_Code'].count()
launches_by_country.sort_values(ascending=False, inplace=True)
launches_by_country
# Out:
# Country_Code
# USA    487
# CHN    158
# FRA     95
# IND     67
# KAZ     46
# JPN     40
# NZL     13
# Name: Country_Code, dtype: int64

# %%
fig = px.choropleth(
    locations=launches_by_country.index,
    locationmode='ISO-3',
    color=launches_by_country.values,
    hover_name=launches_by_country.index,
    color_continuous_scale=px.colors.sequential.matter,
    title='Number of Launches by Country'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a5249aa9-92e5-470c-8bb8-dc2bdad6d1dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a5249aa9-92e5-470c-8bb8-dc2bdad6d1dd")) {                    Plotly.newPlot(                        "a5249aa9-92e5-470c-8bb8-dc2bdad6d1dd",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003elocations=%{location}\u003cbr\u003ecolor=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA","CHN","FRA","IND","KAZ","JPN","NZL"],"locationmode":"ISO-3","locations":["USA","CHN","FRA","IND","KAZ","JPN","NZL"],"name":"","z":{"dtype":"i2","bdata":"5wGeAF8AQwAuACgADQA="},"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar ...

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Failures by Country

# %%
failure_by_country = df_data[df_data['Mission_Status'] == 'Failure'].groupby('Country_Code')['Country_Code'].count()
failure_by_country.sort_values(ascending=False, inplace=True)
failure_by_country
# Out:
# Country_Code
# USA    19
# IND     5
# CHN     4
# FRA     2
# KAZ     2
# NZL     2
# Name: Country_Code, dtype: int64

# %%
failure_by_country_graph = px.choropleth(
    locations=failure_by_country.index,
    locationmode='ISO-3',
    color=failure_by_country.values)

failure_by_country_graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d9f4941f-66a4-4335-8f21-5cfd21b8df10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d9f4941f-66a4-4335-8f21-5cfd21b8df10")) {                    Plotly.newPlot(                        "d9f4941f-66a4-4335-8f21-5cfd21b8df10",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"locations=%{location}\u003cbr\u003ecolor=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"ISO-3","locations":["USA","IND","CHN","FRA","KAZ","NZL"],"name":"","z":{"dtype":"i1","bdata":"EwUEAgIC"},"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"o ...

# %% [markdown]
# # Create a Plotly Sunburst Chart of the countries, organisations, and mission status.

# %%
sunburst_chart = px.sunburst(df_data,
                             path=['Country', 'Organisation', 'Mission_Status'],
                             title='Mission Status by Country and Organisation')
sunburst_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d1d03b5d-a548-4cb6-a7ca-a84dc161f5be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d1d03b5d-a548-4cb6-a7ca-a84dc161f5be")) {                    Plotly.newPlot(                        "d1d03b5d-a548-4cb6-a7ca-a84dc161f5be",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["USA\u002fSpaceX\u002fSuccess","China\u002fCASC\u002fSuccess","Kazakhstan\u002fRoscosmos\u002fSuccess","USA\u002fULA\u002fSuccess","Japan\u002fJAXA\u002fSuccess","USA\u002fNorthrop\u002fSuccess","China\u002fExPace\u002fFailure","New Zealand\u002fRocket Lab\u002fFailure","New Zealand\u002fRocket Lab\u002fSuccess","USA\u002fVirgin Orbit\u002fFailure","Japan\u002fMHI\u002fSuccess","China\u002fCASC\u002fFailure","Kazakhstan\u002fArianespace\u002fSuccess","Russia\u002fVKS RF\u002fSuccess","France\u002fArianespace\u002fSuccess","India\u002fISRO\u002fSuccess","Kazakhstan\u002fILS\u002fSuccess","France\u002fArianespace\u002fFailure","Yellow Sea\u002fCASC\u002fSuccess","Russia\u002fRoscosmos\u002fSuccess","Kazakhstan\u002fVKS RF\u002fSuccess","Russia\u002fEurockot\u002fSuccess","France\u002fArianespace\u002fPartial Failure","India\u002fISRO\u002fFailure","Kazakhstan\u002fRoscosmos\u002fPartial Failure","China\u002fCASC\u002fPartial Failure","USA\u002fSpaceX\u002fPrelaunch Failure","Pacific Missile Range Facility\u002fSandia\u002fFailure","USA\u002fSpaceX\u002fFailure","Russia\u002fKosmotras\u002fSuccess","USA\u002fNorthrop\u002fFailure","Kazakhstan\u002fVKS RF\u002fFailure","Russia\u002fVKS RF\u002fPartial Failure","USA\u002fSpaceX\u002fPartial Failure","France\u002fESA\u002fSuccess","USA\u002fNASA\u002fSuccess","Kazakhstan\u002fKosmotras\u002fSuccess","India\u002fISRO\u002fPartial Failure","USA\u002fULA\u002fPartial Failure","USA\u002fBoeing\u002fSuccess","Kazakhstan\u002fKosmotras\u002fFailure","USA\u002fILS\u002fSuccess","Russia\u002fEurockot\u002fFailure","USA\u002fBoeing\u002fPartial Failure","USA\u002fLockheed\u002fSuccess","USA\u002fNASA\u002fFailure","Gran Canaria\u002fNorthrop\u002fSuccess","USA\u002fEER\u002fFailure","USA\u002fNorthrop\u002fPartial Failure","USA\u002fMartin Marietta\u002fSuccess","USA\u002fMartin Marietta\u002fFailure","Kazakhstan\u002fRVSN USSR\u002fSuccess","USA\u002fUS Air Force\u002fSuccess","USA\u002fNASA\u002fPartial Failure","USA\u002fUS Air Force\u002fPartial Failure","USA\u002fUS Air Force\u002fFailure","USA\u002fSpaceX","China\u002fCASC","Kazakhstan\u002fRoscosmos","USA\u002fULA","Japan\u002fJAXA","USA\u002fNorthrop","China\u002fExPace","New Zealand\u002fRocket Lab","USA\u002fVirgin Orbit","Japan\u002fMHI","Kazakhstan\u002fArianespace","Russia\u002fVKS RF","France\u002fArianespace","India\u002fISRO","Kazakhstan\u002fILS","Yellow Sea\u002fCASC","Russia\u002fRoscosmos","Kazakhstan\u002fVKS RF","Russia\u002fEurockot","Pacific Missile Range Facility\u002fSandia","Russia\u002fKosmotras","France\u002fESA","USA\u002fNASA","Kazakhstan\u002fKosmotras","USA\u002fBoeing","USA\u002fILS","USA\u002fLockheed","Gran Canaria\u002fNorthrop","USA\u002fEER","USA\u002fMartin Marietta","Kazakhstan\u002fRVSN USSR","USA\u002fUS Air Force","USA","China","Kazakhstan","Japan","New Zealand","Russia","France","India","Yellow Sea","Pacific Missile Range Facility","Gran Canaria"],"labels":["Success","Success","Success","Success","Success","Success","Failure","Failure","Success","Failure","Success","Failure","Success","Success","Success","Success","Success","Failure","Success","Success","Success","Success","Partial Failure","Failure","Partial Failure","Partial Failure","Prelaunch Fa ...

# %% [markdown]
# # Analyse the Total Amount of Money Spent by Organisation on Space Missions

# %%
df_data["Price"] = pd.to_numeric(df_data["Price"], errors='coerce')
money_spent_by_organisation = df_data.groupby('Organisation').agg({"Price":"sum"})
money_spent_by_organisation.sort_values(by="Price", ascending=False, inplace=True)
money_spent_by_organisation
# Out:
#                     Price
# Organisation
# NASA            61,200.00
# Arianespace     16,345.00
# ULA             14,798.00
# CASC             6,340.26
# SpaceX           5,444.00
# Northrop         3,930.00
# MHI              3,532.50
# ISRO             2,177.00
# US Air Force     1,550.92
# VKS RF           1,548.90
# ILS              1,320.00
# Boeing           1,241.00
# Roscosmos        1,187.50
# Martin Marietta    721.40
# Kosmotras          638.00
# Eurockot           543.40
# Lockheed           280.00
# JAXA               168.00
# Rocket Lab          97.50
# ESA                 37.00
# ExPace              28.30
# EER                 20.00
# Sandia              15.00
# Virgin Orbit        12.00
# RVSN USSR            0.00

# %% [markdown]
# # Analyse the Amount of Money Spent by Organisation per Launch

# %%
average_spent_per_launch = df_data.groupby('Organisation').agg({"Price": "mean"})
average_spent_per_launch.sort_values(by="Price", ascending=False, inplace=True)
average_spent_per_launch

fig = px.bar(
    average_spent_per_launch,
    x=average_spent_per_launch.index,
    y="Price",
    color=average_spent_per_launch.index,
    title="Average Amount Spent per Launch by Organisation",
    labels={"Price": "Average Price (USD Millions)"},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="89b126b2-539c-4158-916c-4228a4ff7a6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("89b126b2-539c-4158-916c-4228a4ff7a6d")) {                    Plotly.newPlot(                        "89b126b2-539c-4158-916c-4228a4ff7a6d",                        [{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"NASA","orientation":"v","showlegend":true,"textposition":"auto","x":["NASA"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAgfEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Boeing","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Boeing","orientation":"v","showlegend":true,"textposition":"auto","x":["Boeing"],"xaxis":"x","y":{"dtype":"f8","bdata":"kiRJkiQpZkA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arianespace","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Arianespace","orientation":"v","showlegend":true,"textposition":"auto","x":["Arianespace"],"xaxis":"x","y":{"dtype":"f8","bdata":"VVVVVVVIZUA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ULA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ULA","orientation":"v","showlegend":true,"textposition":"auto","x":["ULA"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADgYkA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ILS","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ILS","orientation":"v","showlegend":true,"textposition":"auto","x":["ILS"],"xaxis":"x","y":{"dtype":"f8","bdata":"J3ZiJ3ZiWUA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MHI","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"MHI","orientation":"v","showlegend":true,"textposition":"auto","x":["MHI"],"xaxis":"x","y":{"dtype":"f8","bdata":"5LNuMEXeV0A="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Martin Marietta","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Martin Marietta","orientation":"v","showlegend":true,"textposition":"auto","x":["Martin Marietta"],"xaxis":"x","y":{"dtype":"f8","bdata":"n\u002fRJn\u002fQJVEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"US Air Force","orientation":"v","showlegend":true,"textposition":"auto","x":["US Air Force"],"xaxis":"x","y":{"dtype":"f8","bdata":"z7L5Z0zTTUA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"JAXA","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"JAXA","orientation":"v","showlegend":true,"textposition":"auto","x":["JAXA"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAATEA="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u ...

# %% [markdown]
# # Chart the Number of Launches per Year

# %%
df_data["Date"] = pd.to_datetime(df_data['Date'], format='%a %b %d, %Y %H:%M %Z', utc=True, errors='coerce')
df_data["Year"] = df_data["Date"].dt.year.astype("Int64")
df_data["Year"]
# Out:
# 0       2020
# 1       2020
# 3       2020
# 4       2020
# 5       2020
#         ...
# 3855    1966
# 3971    1965
# 3993    1965
# 4000    1964
# 4020    1964
# Name: Year, Length: 964, dtype: Int64

# %%
launches_per_year = df_data.groupby("Year").agg({"Year": "count"})
launches_per_year
# Out:
#       Year
# Year
# 1964     2
# 1965     2
# 1966     3
# 1967     7
# 1968    10
# 1969     8
# 1970     1
# 1971     2
# 1972     2
# 1973     1
# 1981     2
# 1982     4
# 1983     5
# 1984     6
# 1985    10
# 1986     3
# 1987     3
# 1988     5
# 1989     6
# 1990    11
# 1991     7
# 1992    12
# 1993    12
# 1994    16
# 1995    10
# 1996    14
# 1997    18
# 1998    18
# 1999    13
# 2000    16
# 2001    10
# 2002    16
# 2003    20
# 2004    17
# 2005    15
# 2006    27
# 2007    29
# 2008    28
# 2009    31
# 2010    29
# 2011    29
# 2012    24
# 2013    33
# 2014    41
# 2015    37
# 2016    64
# 2017    66
# 2018    88
# 2019    73
# 2020    52

# %%
fig=px.bar(launches_per_year,
           x=launches_per_year.index,
           y="Year",
           color="Year")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d189084a-477f-438d-8e29-100df5ec532d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d189084a-477f-438d-8e29-100df5ec532d")) {                    Plotly.newPlot(                        "d189084a-477f-438d-8e29-100df5ec532d",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eYear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i1","bdata":"AgIDBwoIAQICAQIEBQYKAwMFBgsHDAwQCg4SEg0QChAUEQ8bHRwfHR0YISklQEJYSTQ="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i2","bdata":"rAetB64HrwewB7EHsgezB7QHtQe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wfkBw=="},"xaxis":"x","y":{"dtype":"i1","bdata":"AgIDBwoIAQICAQIEBQYKAwMFBgsHDAwQCg4SEg0QChAUEQ8bHRwfHR0YISklQEJYSTQ="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"mar ...

# %% [markdown]
# # Chart the Number of Launches Month-on-Month until the Present
#
# Which month has seen the highest number of launches in all time? Superimpose a rolling average on the month on month time series chart.

# %%
df_data["Month"] = df_data["Date"].dt.month.astype("Int64")
launches_by_month = df_data.groupby("Month").agg({"Month": "count"})
launches_by_month
# Out:
#        Month
# Month
# 1         66
# 2         60
# 3         77
# 4         88
# 5         86
# 6         85
# 7         77
# 8         82
# 9         87
# 10        83
# 11        76
# 12        91

# %%
fig = px.bar(launches_by_month,
                   x=launches_by_month.index,
                   y="Month",
                   color="Month",
                   title="Number of Launches per Month",
                   labels={"Month": "Number of Launches"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="124fde2b-80cc-4f9d-b96d-c3adbe98c171" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("124fde2b-80cc-4f9d-b96d-c3adbe98c171")) {                    Plotly.newPlot(                        "124fde2b-80cc-4f9d-b96d-c3adbe98c171",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eNumber of Launches=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i1","bdata":"QjxNWFZVTVJXU0xb"},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"xaxis":"x","y":{"dtype":"i1","bdata":"QjxNWFZVTVJXU0xb"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","lin ...

# %% [markdown]
# # Launches per Month: Which months are most popular and least popular for launches?
#
# Some months have better weather than others. Which time of year seems to be best for space missions?

# %%
best_launch_month = launches_by_month["Month"].idxmax()

print(f"The month with the highest number of launches is: {best_launch_month}")
# Out:
# The month with the highest number of launches is: 12

# %% [markdown]
# # How has the Launch Price varied Over Time?
#
# Create a line chart that shows the average price of rocket launches over time.

# %%
price_over_time = df_data.groupby("Year").agg({"Price": "mean"})
price_over_time = price_over_time.dropna()
avg_price_over_time = price_over_time.rolling(window=5).mean()
avg_price_over_time
# Out:
#       Price
# Year
# 1964    NaN
# 1965    NaN
# 1966    NaN
# 1967    NaN
# 1968  60.69
# 1969  59.85
# 1981 137.20
# 1982 194.44
# 1983 255.87
# 1984 320.10
# 1985 389.91
# 1986 361.97
# 1987 299.09
# 1988 274.15
# 1989 274.29
# 1990 250.50
# 1991 266.73
# 1992 324.44
# 1993 331.50
# 1994 299.63
# 1995 306.80
# 1996 277.16
# 1997 257.64
# 1998 232.71
# 1999 215.64
# 2000 185.27
# 2001 194.77
# 2002 189.50
# 2003 175.17
# 2004 166.49
# 2005 151.02
# 2006 120.60
# 2007 106.67
# 2008 116.52
# 2009 134.03
# 2010 144.55
# 2011 146.15
# 2012 146.23
# 2013 138.39
# 2014 122.84
# 2015 112.35
# 2016  98.92
# 2017  87.60
# 2018  82.44
# 2019  73.85
# 2020  65.99

# %%
fig = px.line(avg_price_over_time,
              x=avg_price_over_time.index,
              y="Price",
              title="Average Price of Rocket Launches Over Time",
              labels={"Price": "Average Price (USD Millions)"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="90351a7f-422e-4c87-99a1-8c74d07294da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("90351a7f-422e-4c87-99a1-8c74d07294da")) {                    Plotly.newPlot(                        "90351a7f-422e-4c87-99a1-8c74d07294da",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eAverage Price (USD Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"rAetB64HrwewB7EHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H9+arx0k1hOQEA1XrpJ7E1AZmZmZmYmYUCuR+F6FE5oQJVDi2zn+29Anqh\u002fI5QBdEAywYN5ol54QHNoke18n3ZAxSCwcmixckB1kxgEViJxQH9qvHSTJHFA2Ih\u002fjfhPb0B0r9YbtKtwQGY7\u002fNoMR3RAG71K9vS3dEAfWoHGHrpyQNIardHaLHNADcMwDINScUCknlBwKxpwQG66cwjUFm1AnvMQs6H0akDIT6B1lyhnQNWIl0+dWGhA5r+Nnt6vZ0CiELCcj+VlQD0Si3Sbz2RAor8ZfrngYkDWUYwfpSZeQD2MyXTGqlpAnodSUgEhXUC63wuS1MBgQCL\u002fSVWDEWJAqPGpLKdEYkBnmQieN0diQCtJ1r5bTGFAk0N8kbK1XkDSAu76URZcQAaZNznwulhAUYpItGXmVUCG8f2NIpxUQGQDat57dlJA8qDjr3Z\u002fUEA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"# ...

# %% [markdown]
# # Chart the Number of Launches over Time by the Top 10 Organisations.
#
# How has the dominance of launches changed over time between the different players?

# %%
top_10_organisations = launches_by_company.head(10)

fig = px.bar(top_10_organisations,
             x=top_10_organisations.index,
             y="Organisation",
             color=top_10_organisations.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="9b8445b1-a2e2-406f-b710-d177b73a1ae3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9b8445b1-a2e2-406f-b710-d177b73a1ae3")) {                    Plotly.newPlot(                        "9b8445b1-a2e2-406f-b710-d177b73a1ae3",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CASC","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CASC","orientation":"v","showlegend":true,"textposition":"auto","x":["CASC"],"xaxis":"x","y":{"dtype":"i2","bdata":"ngA="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"NASA","orientation":"v","showlegend":true,"textposition":"auto","x":["NASA"],"xaxis":"x","y":{"dtype":"i2","bdata":"lQA="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SpaceX","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"SpaceX","orientation":"v","showlegend":true,"textposition":"auto","x":["SpaceX"],"xaxis":"x","y":{"dtype":"i1","bdata":"Yw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ULA","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ULA","orientation":"v","showlegend":true,"textposition":"auto","x":["ULA"],"xaxis":"x","y":{"dtype":"i1","bdata":"Yg=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arianespace","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Arianespace","orientation":"v","showlegend":true,"textposition":"auto","x":["Arianespace"],"xaxis":"x","y":{"dtype":"i1","bdata":"YA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northrop","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Northrop","orientation":"v","showlegend":true,"textposition":"auto","x":["Northrop"],"xaxis":"x","y":{"dtype":"i1","bdata":"Uw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ISRO","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"ISRO","orientation":"v","showlegend":true,"textposition":"auto","x":["ISRO"],"xaxis":"x","y":{"dtype":"i1","bdata":"Qw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MHI","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"MHI","orientation":"v","showlegend":true,"textposition":"auto","x":["MHI"],"xaxis":"x","y":{"dtype":"i1","bdata":"JQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"VKS RF","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"VKS RF","orientation":"v","showlegend":true,"textposition":"auto","x":["VKS RF"],"xaxis":"x","y":{"dtype":"i1","bdata":"IQ=="},"yaxis":"y","type":"bar"},{"hovertemplate":"index=%{x}\u003cbr\u003eOrganisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"US Air Force","orientation":"v","showlegend":true,"textposition":"auto","x":["US Air Force"],"xaxis":"x","y":{"dtype":"i1","bdata":"Gg=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2d ...

# %% [markdown]
# # Cold War Space Race: USA vs USSR
#
# The cold war lasted from the start of the dataset up until 1991.

# %%
df_russia = df_data[df_data['Country'] == 'Russia']
df_usa = df_data[df_data['Country'] == 'USA']
df_usa_vs_russia = pd.concat([df_russia, df_usa])
df_usa_vs_russia
# Out:
#       Unnamed: 0.1  Unnamed: 0  Organisation  \
# 46              46          46        VKS RF
# 64              64          64        VKS RF
# 73              73          73        VKS RF
# 97              97          97        VKS RF
# 105            105         105        VKS RF
# ...            ...         ...           ...
# 3855          3855        3855  US Air Force
# 3971          3971        3971  US Air Force
# 3993          3993        3993  US Air Force
# 4000          4000        4000  US Air Force
# 4020          4020        4020  US Air Force
#
#                                       Location                      Date  \
# 46      Site 43/3, Plesetsk Cosmodrome, Russia 2020-02-20 08:24:00+00:00
# 64     Site 133/3, Plesetsk Cosmodrome, Russia 2019-12-26 23:11:00+00:00
# 73      Site 43/3, Plesetsk Cosmodrome, Russia 2019-12-11 08:54:00+00:00
# 97      Site 43/4, Plesetsk Cosmodrome, Russia 2019-09-26 07:46:00+00:00
# 105    Site 133/3, Plesetsk Cosmodrome, Russia 2019-08-30 14:00:00+00:00
# ...                                        ...                       ...
# 3855   SLC-4W, Vandenberg AFB, California, USA 1966-07-29 18:43:00+00:00
# 3971  SLC-20, Cape Canaveral AFS, Florida, USA 1965-05-06 15:00:00+00:00
# 3993  SLC-20, Cape Canaveral AFS, Florida, USA 1965-02-11 15:19:00+00:00
# 4000  SLC-20, Cape Canaveral AFS, Florida, USA 1964-12-10 16:52:00+00:00
# 4020  SLC-20, Cape Canaveral AFS, Florida, USA 1964-09-01 15:00:00+00:00
#
#                                                  Detail  Rocket_Status  Price  \
# 46              Soyuz 2.1a/Fregat-M | Meridian-M n†­19L   StatusActive  48.50
# 64    Rokot/Briz KM | Gonets-M ???24, 25, 26 [block-...  StatusRetired  41.80
# 73                      Soyuz 2.1b/Fregat | Cosmos 2544   StatusActive  48.50
# 97                      Soyuz 2.1b/Fregat | Cosmos 2541   StatusActive  48.50
# 105                         Rokot/Briz KM | Cosmos 2540  StatusRetired  41.80
# ...                                                 ...            ...    ...
# 3855                                  Titan IIIB | KH-8  StatusRetired  59.00
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired  63.23
# 3993                                 Titan IIIA | LES 1  StatusRetired  63.23
# 4000                           Titan IIIA | Transtage 2  StatusRetired  63.23
# 4020                           Titan IIIA | Transtage 1  StatusRetired  63.23
#
#      Mission_Status Country Country_Code  Year  Month
# 46          Success  Russia          NaN  2020      2
# 64          Success  Russia          NaN  2019     12
# 73          Success  Russia          NaN  2019     12
# 97          Success  Russia          NaN  2019      9
# 105         Success  Russia          NaN  2019      8
# ...             ...     ...          ...   ...    ...
# 3855        Success     USA          USA  1966      7
# 3971        Success     USA          USA  1965      5
# 3993        Success     USA          USA  1965      2
# 4000        Success     USA          USA  1964     12
# 4020        Failure     USA          USA  1964      9
#
# [541 rows x 13 columns]

# %% [markdown]
# ## Create a Plotly Pie Chart comparing the total number of launches of the USSR and the USA
#
# Hint: Remember to include former Soviet Republics like Kazakhstan when analysing the total number of launches.

# %%
launches_by_country_usa_ussr = df_usa_vs_russia.groupby('Country')['Country'].count()

fig = px.pie(
    values=launches_by_country_usa_ussr.values,
    names=launches_by_country_usa_ussr.index,
    title="Launches by Country: USA vs. USSR/Russia",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ed8511fa-5a93-47bd-a90f-846c0ecb1a5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ed8511fa-5a93-47bd-a90f-846c0ecb1a5e")) {                    Plotly.newPlot(                        "ed8511fa-5a93-47bd-a90f-846c0ecb1a5e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Russia","USA"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"NgDnAQ=="},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scattermap":[{"type":"scattermap","marker":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# ## Create a Chart that Shows the Total Number of Launches Year-On-Year by the Two Superpowers

# %%
launches_by_year_country = df_usa_vs_russia.groupby(['Year', 'Country'])['Country'].count().unstack()

fig = px.line(
    launches_by_year_country,
    x=launches_by_year_country.index,
    y=['USA', 'Russia'],
    title='Year-on-Year Launches: USA vs. Russia/USSR',
    labels={'value': 'Number of Launches', 'variable': 'Country'},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6726e91b-e7d7-4e1a-b087-a044cf10a2ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6726e91b-e7d7-4e1a-b087-a044cf10a2ec")) {                    Plotly.newPlot(                        "6726e91b-e7d7-4e1a-b087-a044cf10a2ec",                        [{"hovertemplate":"Country=USA\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Launches=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"USA","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"rAetB64HrwewB7EHsgezB7QHtQe9B74HvwfAB8EHwgfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russia\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Launches=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russia","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"rAetB64HrwewB7EHsgezB7QHtQe9B74HvwfAB8EHwgfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAADwPwAAAAAAAPh\u002fAAAAAAAAAEAAAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAAAEAAAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAAAEAAAAAAAAAIQAAAAAAAAAhAAAAAAAAAAEAAAAAAAADwPwAAAAAAABhAAAAAAAAAEEAAAAAAAAAIQAAAAAAAABRAAAAAAAAAAEAAAAAAAAAYQAAAAAAAABRAAAAAAAAA8D8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111 ...

# %% [markdown]
# ## Chart the Total Number of Mission Failures Year on Year.

# %%
mission_failures_by_year = df_data[df_data['Mission_Status'] == 'Failure'].groupby('Year')['Year'].count()
# print(mission_failures_by_year)

fig = px.bar(
    mission_failures_by_year,
    x=mission_failures_by_year.index,
    y='Year',
    title='Total Number of Mission Failures Year on Year',
    labels={'Year': 'Number of Failures'},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0321c174-a72f-4dce-942b-e7ff4620bb1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0321c174-a72f-4dce-942b-e7ff4620bb1e")) {                    Plotly.newPlot(                        "0321c174-a72f-4dce-942b-e7ff4620bb1e",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eNumber of Failures=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":{"dtype":"i2","bdata":"rAfCB8YHyQfKB8sHzAfRB9IH0wfVB9YH1wfYB9kH2gfbB90H3gffB+AH4QfjB+QH"},"xaxis":"x","y":{"dtype":"i1","bdata":"AQEBAgECAQEBAQEDAQEBAgEBAQEBAgIE"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line": ...

# %% [markdown]
# ## Chart the Percentage of Failures over Time
#
# Did failures go up or down over time? Did the countries get better at minimising risk and improving their chances of success over time?

# %%
df_data['Year'] = pd.to_datetime(df_data['Date']).dt.year
total_launches_by_year = df_data.groupby('Year')['Mission_Status'].count()
failures_by_year = df_data[df_data['Mission_Status'] == 'Failure'].groupby('Year')['Mission_Status'].count()
failure_percentage_by_year = (failures_by_year / total_launches_by_year * 100).fillna(0)

fig = px.line(
    failure_percentage_by_year,
    x=failure_percentage_by_year.index,
    y=failure_percentage_by_year.values,
    title='Percentage of Mission Failures Over Time',
    labels={'x': 'Year', 'y': 'Percentage of Failures'},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c3bf4976-d17c-49eb-96ff-1342c19652fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c3bf4976-d17c-49eb-96ff-1342c19652fd")) {                    Plotly.newPlot(                        "c3bf4976-d17c-49eb-96ff-1342c19652fd",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003ePercentage of Failures=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outli ...

# %% [markdown]
# # For Every Year Show which Country was in the Lead in terms of Total Number of Launches up to and including including 2020)
#
# Do the results change if we only look at the number of successful launches?

# %%
successful_launches_by_year_country = df_data[df_data['Mission_Status'] == 'Success'].groupby(['Year', 'Country'])['Country'].count().unstack()

leading_country_successful = successful_launches_by_year_country.idxmax(axis=1)

print("Leading Country Based on Successful Launches (up to 2020):")
leading_country_successful
# Out:
# Leading Country Based on Successful Launches (up to 2020):
# Year
# 1,964.00      USA
# 1,965.00      USA
# 1,966.00      USA
# 1,967.00      USA
# 1,968.00      USA
# 1,969.00      USA
# 1,970.00      USA
# 1,971.00      USA
# 1,972.00      USA
# 1,973.00      USA
# 1,981.00      USA
# 1,982.00      USA
# 1,983.00      USA
# 1,984.00      USA
# 1,985.00      USA
# 1,986.00    China
# 1,987.00    China
# 1,988.00      USA
# 1,989.00      USA
# 1,990.00      USA
# 1,991.00      USA
# 1,992.00      USA
# 1,993.00      USA
# 1,994.00      USA
# 1,995.00      USA
# 1,996.00      USA
# 1,997.00      USA
# 1,998.00      USA
# 1,999.00      USA
# 2,000.00      USA
# 2,001.00      USA
# 2,002.00      USA
# 2,003.00      USA
# 2,004.00    China
# 2,005.00      USA
# 2,006.00      USA
# 2,007.00      USA
# 2,008.00      USA
# 2,009.00      USA
# 2,010.00      USA
# 2,011.00      USA
# 2,012.00      USA
# 2,013.00      USA
# 2,014.00      USA
# 2,015.00      USA
# 2,016.00      USA
# 2,017.00      USA
# 2,018.00      USA
# 2,019.00    China
# 2,020.00      USA
# dtype: object

# %% [markdown]
# # Create a Year-on-Year Chart Showing the Organisation Doing the Most Number of Launches
#
# Which organisation was dominant in the 1970s and 1980s? Which organisation was dominant in 2018, 2019 and 2020?

# %%
launches_by_year_org = df_data.groupby(['Year', 'Organisation'])['Organisation'].count().unstack()
dominant_org_by_year = launches_by_year_org.idxmax(axis=1)

fig = px.bar(
    launches_by_year_org,
    x=dominant_org_by_year.index,
    y=dominant_org_by_year.values,
    title='Dominant Organisation in Space Launches Year-on-Year',
    labels={'value': 'Dominant Organisation', 'x': 'Year'},
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="be03e3a2-59dc-46ea-92ca-5f555228efac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("be03e3a2-59dc-46ea-92ca-5f555228efac")) {                    Plotly.newPlot(                        "be03e3a2-59dc-46ea-92ca-5f555228efac",                        [{"hovertemplate":"variable=US Air Force\u003cbr\u003eYear=%{x}\u003cbr\u003eDominant Organisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"US Air Force","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAAAAQAAAAAAAAAhAAAAAAAAAGEAAAAAAAAAgQAAAAAAAABBAAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"variable=NASA\u003cbr\u003eYear=%{x}\u003cbr\u003eDominant Organisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NASA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"NASA","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\\u002fAAAAAAAA+H8AAAAAAADwPwAAAAAAAAhAAAAAAAAACEAAAAAAAAAQQAAAAAAAABhAAAAAAAAACEAAAAAAAAAIQAAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"variable=CASC\u003cbr\u003eYear=%{x}\u003cbr\u003eDominant Organisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CASC","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CASC","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAA+H8AAAAAAADwPwAAAAAAAPh\u002fAAAAAAAAAEAAAAAAAADwPwAAAAAAAAhAAAAAAAAA+H8AAAAAAADwPwAAAAAAAAhAAAAAAAAAEEAAAAAAAAAIQAAAAAAAAAhAAAAAAAAA+H8AAAAAAAAAQAAAAAAAABRAAAAAAAAAIEAAAAAAAAAIQAAAAAAAABRAAAAAAAAAIEAAAAAAAAAYQAAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAALkAAAAAAAAAoQAAAAAAAADtAAAAAAAAANUAAAAAAAAAwQA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"variable=Northrop\u003cbr\u003eYear=%{x}\u003cbr\u003eDominant Organisation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Northrop","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Northrop","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"..."},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAA ...
